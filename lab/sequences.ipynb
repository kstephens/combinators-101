# %% [markdown]
# # (Imports)

# %%
import sys; sys.path.append('..')
from c101.helpers import *
import operator as op
#from c101.seq import empty, first, rest, cons, cons_list, map, reduce, iterable
import c101.seq as sq
import inspect

# %%
cl = sq.cons_list((1, 2, 3))
cl
sq.first(cl)
sq.first(sq.rest(cl))
sq.first(sq.rest(sq.rest(cl)))
sq.rest(sq.rest(sq.rest(cl)))

itr = sq.iterable((1, 2, 3))
tuple(sq.each(cl))

cl = sq.cons(1, (2, 3))
tuple(sq.each(cl))
# Out:
# sq.Cons(...)
# 1
# 2
# 3
# sq.null
#   #>> seq: sq.Cons(...)
#   #>> seq: sq.Cons(...)
#   #>> seq: sq.Cons(...)
#   #>> seq: sq.null
# (1, 2, 3)
#   #>> seq: sq.Cons(...)
#   #>> seq: sq.SeqIterable(...)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 12
#       9 tuple(sq.each(cl))
#      11 cl = sq.cons(1, (2, 3))
# ---> 12 tuple(sq.each(cl))
#
# File ~/local/src/combinators-101/c101/../c101/seq.py:121, in each(seq)
#     120 def each(seq):
# --> 121    while not empty(ic(seq)):
#     122       yield first(seq)
#     123       seq = rest(seq)
#
# File ~/local/src/combinators-101/c101/../c101/seq.py:30, in empty(seq)
#      29 def empty(seq):
# ---> 30    return seq is null or seq.empty()
#
# File ~/local/src/combinators-101/c101/../c101/seq.py:74, in Lazy.empty(self)
#      73 def empty(self):
# ---> 74    return empty(self._check())
#
# ...
